# %%
import pandas as pd

filtered_chains_df= pd.read_csv('chicago_food_inspections/filtered_chains.csv')
filtered_chains_df.head()
# Out:
#    Unnamed: 0  Inspection ID    DBA Name          AKA Name  License #  \
# 0         269        2346124  MCDONALD'S        MCDONALD'S  1332927.0
# 1         293        2346050  MCDONALD'S  MCDONALD'S #5293  2694085.0
# 2         306        2346054  MCDONALD'S        MCDONALD'S  2423993.0
# 3         574        2345583  MCDONALD'S        McDONALD'S  2578350.0
# 4         979        2320903  MCDONALD'S  MCDONALDS #27672  1518455.0
#
#   Facility Type             Risk                Address     City State  ...  \
# 0    Restaurant  Risk 2 (Medium)      2438 W CERMAK RD   CHICAGO    IL  ...
# 1    Restaurant  Risk 2 (Medium)    8321 S ASHLAND AVE   CHICAGO    IL  ...
# 2    Restaurant  Risk 2 (Medium)    8321 S ASHLAND AVE   CHICAGO    IL  ...
# 3    Restaurant  Risk 2 (Medium)    2005 W Chicago AVE   CHICAGO    IL  ...
# 4    Restaurant  Risk 2 (Medium)  5200 S LAKE PARK AVE   CHICAGO    IL  ...
#
#               Results                                         Violations  \
# ...

# %%
filtered_chains_df.columns
# Out:
# Index(['Unnamed: 0', 'Inspection ID', 'DBA Name', 'AKA Name', 'License #',
#        'Facility Type', 'Risk', 'Address', 'City', 'State', 'Zip',
#        'Inspection Date', 'Inspection Type', 'Results', 'Violations',
#        'Latitude', 'Longitude', 'Location', 'Historical Wards 2003-2015',
#        'Zip Codes', 'Community Areas', 'Census Tracts', 'Wards'],
#       dtype='object')
